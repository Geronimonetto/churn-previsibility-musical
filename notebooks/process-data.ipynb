# %%
import kagglehub

cache_path = kagglehub.dataset_download("barun2104/telecom-churn")
print(cache_path)

import shutil
import os

destino = "../data/telecom-churn"
os.makedirs(destino, exist_ok=True)

shutil.copytree(
    cache_path,
    destino,
    dirs_exist_ok=True
)

print("Dataset copiado para:", destino)
# Out:
# C:\Users\GERONIMO\.cache\kagglehub\datasets\barun2104\telecom-churn\versions\2
# Dataset copiado para: ..data/telecom-churn
